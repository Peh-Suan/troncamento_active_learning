# %%
from troncamento_datasets import BaseDataset, SegmentPairDataset
from model import MisalignmentDetector
import torch, torch.nn as nn
import pandas as pd
import os
import tqdm
import utils
max_uncertainty = None

# %%
device = "mps"

model = MisalignmentDetector().to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
criterion = nn.BCEWithLogitsLoss(reduction="none")

pretrain_ckpt = "model_ckpt/prepretrain.pt"
if os.path.isfile(pretrain_ckpt):
    model.load_state_dict(torch.load(pretrain_ckpt))
    print(f"Loaded pre-trained model from {pretrain_ckpt}")

# %%
import glob
saved_embed_fs = glob.glob("saved_embeds/*.npy")

# %%
df = pd.read_csv("troncamento_data.csv")

# %%
df = df[df["sent_it_prob"]>0.99].reset_index(drop=True)

# %%
selected_ids = [int(os.path.basename(f).split("_")[0]) for f in saved_embed_fs]

# %%
df = df[df["id"].isin(selected_ids)].reset_index(drop=True)

# %%
print(f"Using {len(df)} samples for training after filtering by saved embeddings and sent_it_prob > 0.99")
# Out:
# Using 75956 samples for training after filtering by saved embeddings and sent_it_prob > 0.99

# %% [markdown]
# ## Pretraining

# %%
target_basedataset = BaseDataset(df, dataset_type="target", return_player=False)
target_dataset = SegmentPairDataset(target_basedataset)
pretrain_basedataset = BaseDataset(df, dataset_type="pre_train", return_player=False)
pretrain_dataset = SegmentPairDataset(pretrain_basedataset)

# %%
# utils.pretrain_one_epoch(pretrain_dataset, model, optimizer, device, pretrain_ckpt)

# %% [markdown]
# ## Active learning loop

# %%
# for i in tqdm.tqdm(target_dataset): pass

# %%
import shutil
import subprocess

# %%
utils.train_on_gold_dataset(MisalignmentDetector, "model_ckpt", target_basedataset, batch_size=8, pretained_ckpt="model_ckpt/prepretrain.pt", device=device, do_eval=True, train_type="pretrain", upsample_ratio=0, save_ckpt="pretrain.pt")
_ = shutil.copy("model_ckpt/pretrain.pt", "model_ckpt/train.pt")
# Out:
# Positive samples: 225, Negative samples: 103, Target samples per class: 225
# Upsampled negative samples by 0
# Upsampled bad samples by 0
# Training on 376 gold samples (pretrain).
# Positive samples: 59, Negative samples: 18, Bad samples: 17
# Validation on 94 gold samples.
# gold epoch 1/200: 100%|██████████| 47/47 [00:01<00:00, 34.14it/s, bad=0.298, loss=0.854, vowel=0.556]
# gold epoch 2/200: 100%|██████████| 47/47 [00:00<00:00, 68.77it/s, bad=0.16, loss=0.746, vowel=0.585]
# gold epoch 3/200: 100%|██████████| 47/47 [00:00<00:00, 65.54it/s, bad=0.377, loss=1.15, vowel=0.769]
# gold epoch 4/200: 100%|██████████| 47/47 [00:00<00:00, 68.68it/s, bad=0.325, loss=0.839, vowel=0.514]
# gold epoch 5/200: 100%|██████████| 47/47 [00:00<00:00, 70.29it/s, bad=0.594, loss=1, vowel=0.409]
# gold epoch 6/200: 100%|██████████| 47/47 [00:00<00:00, 73.64it/s, bad=0.406, loss=0.852, vowel=0.446]
# gold epoch 7/200: 100%|██████████| 47/47 [00:00<00:00, 77.10it/s, bad=0.567, loss=0.967, vowel=0.401]
# gold epoch 8/200: 100%|██████████| 47/47 [00:00<00:00, 72.27it/s, bad=0.456, loss=1.09, vowel=0.637]
# gold epoch 33/200: 100%|██████████| 47/47 [00:00<00:00, 70.65it/s, bad=0.124, loss=0.744, vowel=0.62]
# gold epoch 34/200: 100%|██████████| 47/47 [00:00<00:00, 66.28it/s, bad=0.484, loss=1.34, vowel=0.853]
# Early stopping. Best val loss 0.8342 at epoch 30.
# Model checkpoint saved at model_ckpt/pretrain.pt

# %%
model.load_state_dict(torch.load("model_ckpt/train.pt"))
max_uncertainty = utils.select_uncertain_samples(model, target_basedataset, k=3, device=device, random_sample=10000, most_certain=False, max_uncertainty=max_uncertainty)
utils.put_files_to_folder(target_basedataset, folder_path="selected_samples", tgrd_fs_folder="it_vxc_textgrids17_acoustic17")
for f in sorted(os.listdir("selected_samples")):
    if f.endswith(".TextGrid") or f.endswith(".wav") or f.endswith(".mp3"):
        _ = subprocess.run(["open", os.path.join("selected_samples", f)])
# Out:
# scoring pool: 100%|██████████| 10000/10000 [00:24<00:00, 411.15it/s]
# /Users/pohsuan/Projects/troncamento/troncamento_datasets.py:301: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gold_labels = pd.concat([gold_labels, pd.DataFrame([new_entry])], ignore_index=True)
# /Users/pohsuan/Projects/troncamento/troncamento_datasets.py:301: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gold_labels = pd.concat([gold_labels, pd.DataFrame([new_entry])], ignore_index=True)
# /Users/pohsuan/Projects/troncamento/troncamento_datasets.py:301: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gold_labels = pd.concat([gold_labels, pd.DataFrame([new_entry])], ignore_index=True)

# %% [markdown]
# ## Train on gold data

# %%
utils.train_on_gold_dataset(MisalignmentDetector, "model_ckpt", target_basedataset, batch_size=4, device=device, do_eval=True, train_type="pretrain", pretained_ckpt="model_ckpt/pretrain.pt", upsample_ratio=0, save_ckpt="train.pt")
utils.delete_annotated_files(target_basedataset, folder_path="selected_samples")
utils.put_files_to_folder(target_basedataset, folder_path="selected_samples", tgrd_fs_folder="it_vxc_textgrids17_acoustic17")
_ = subprocess.run(["osascript", "-e", f'tell application "Praat" to quit'])
for plot_name in ["cm_bad.png", "cm_vowel.png", "val_curve.png", "roc_bad.png", "roc_vowel.png", "score_dist_bad.png", "score_dist_vowel.png"]:
    n_plots = len([f for f in os.listdir("log_plots") if f.startswith(plot_name.replace(".png", ""))])
    _ = shutil.copy(os.path.join("model_ckpt", plot_name), os.path.join("log_plots", plot_name.replace(".png", f"_{n_plots}.png")))
    os.remove(os.path.join("model_ckpt", plot_name))
# Out:
# Loaded pretrained model from model_ckpt/pretrain.pt
# Positive samples: 229, Negative samples: 107, Target samples per class: 229
# Upsampled negative samples by 0
# Upsampled bad samples by 0
# Training on 403 gold samples (pretrain).
# Positive samples: 63, Negative samples: 21, Bad samples: 16
# Validation on 100 gold samples.
# gold epoch 1/200: 100%|██████████| 101/101 [00:01<00:00, 59.89it/s, bad=0.0156, loss=1.17, vowel=1.15]
# gold epoch 2/200: 100%|██████████| 101/101 [00:01<00:00, 67.39it/s, bad=0.0973, loss=0.365, vowel=0.267]
# gold epoch 3/200: 100%|██████████| 101/101 [00:01<00:00, 64.64it/s, bad=0.569, loss=0.775, vowel=0.206]
# gold epoch 4/200: 100%|██████████| 101/101 [00:01<00:00, 70.64it/s, bad=0.307, loss=0.833, vowel=0.526]
# gold epoch 5/200: 100%|██████████| 101/101 [00:01<00:00, 74.52it/s, bad=0.063, loss=0.313, vowel=0.25]
# gold epoch 6/200: 100%|██████████| 101/101 [00:01<00:00, 79.42it/s, bad=0.0561, loss=0.26, vowel=0.204]
# gold epoch 7/200: 100%|██████████| 101/101 [00:01<00:00, 82.01it/s, bad=0.0827, loss=0.32, vowel=0.237]
# Early stopping. Best val loss 0.7541 at epoch 3.
# Model checkpoint saved at model_ckpt/train.pt

# %%
preds = []
for data in tqdm.tqdm(target_dataset):
    x, phone_ids, silver_label, y = data

    logit = model(
        x.unsqueeze(0).to(device),
        phone_ids.unsqueeze(0).to(device),
        silver_label.unsqueeze(0).to(device)
    ).squeeze(0)

    p = torch.sigmoid(logit)
    pred = (p >= 0.5)
    preds.append(pred.cpu())
# Out:
#   0%|          | 0/29519 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 3
#       1 preds = []
#       2 for data in tqdm.tqdm(target_dataset):
# ----> 3     x, phone_ids, silver_label, y = data
#       5     logit = model(
#       6         x.unsqueeze(0).to(device),
#       7         phone_ids.unsqueeze(0).to(device),
#       8         silver_label.unsqueeze(0).to(device)
#       9     ).squeeze(0)
#      11     p = torch.sigmoid(logit)
#
# ValueError: too many values to unpack (expected 4)

# %%
print(f'''
All: {len(preds)}
Positive: {preds.count(1)}
Negative: {preds.count(0)}
Percentage: {preds.count(0)/len(preds):.2%}
''')
# Out:
# All: 54794
# Positive: 29778
# Negative: 25016
# Percentage: 45.65%

# %%
log_df = pd.read_csv("uncertainty_log.csv")

import seaborn as sns
import matplotlib.pyplot as plt
log_df["idx"] = log_df["idx"]+1
sns.lineplot(data=log_df, x="idx", y="mean_uncertainty", label="All samples")
sns.lineplot(data=log_df, x="idx", y="selected_mean_uncertainty", label="Selected samples")
plt.ylabel("Mean uncertainty")
plt.xlabel("Selection iteration")
plt.savefig("log_plots/all_uncertainty_over_iterations.png")
# plt.xticks(range(1, len(log_df)+1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 6
#       4 import matplotlib.pyplot as plt
#       5 log_df["idx"] = log_df["idx"]+1
# ----> 6 sns.lineplot(data=log_df, x="idx", y="mean_uncertainty", label="All samples")
#       7 sns.lineplot(data=log_df, x="idx", y="selected_mean_uncertainty", label="Selected samples")
#       8 plt.ylabel("Mean uncertainty")
#
# File ~/miniconda3/envs/default_env/lib/python3.11/site-packages/seaborn/relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)
#     481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
#     486         data=data,
#     487         variables=dict(
#     488             x=x, y=y, hue=hue, size=size, style=style, units=units, weight=weights
#     489         ),
#     490         estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     491         sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     492         legend=legend,
#     493     )
#     495     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     496     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~/miniconda3/envs/default_env/lib/python3.11/site-packages/seaborn/relational.py:216, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     202 def __init__(
#     203     self, *,
#     204     data=None, variables={},
#    (...)
#     210     # the kind of plot to draw, but for the time being we need to set
#     211     # this information so the SizeMapping can use it
#     212     self._default_size_range = (
#     213         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     214     )
# --> 216     super().__init__(data=data, variables=variables)
#     218     self.estimator = estimator
#     219     self.errorbar = errorbar
#
# File ~/miniconda3/envs/default_env/lib/python3.11/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~/miniconda3/envs/default_env/lib/python3.11/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~/miniconda3/envs/default_env/lib/python3.11/site-packages/seaborn/_core/data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~/miniconda3/envs/default_env/lib/python3.11/site-packages/seaborn/_core/data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `mean_uncertainty` for `y`. An entry with this name does not appear in `data`.

# %%
from PIL import Image, ImageDraw, ImageFont
import glob
import os
import re

png_files = sorted(glob.glob("log_plots/prob_hist_vowel_*.png"))
png_files = [f"log_plots/prob_hist_vowel_{i}.png" for i in range(len(png_files))]

frames = []

# Try to load a nicer font; fall back to default if unavailable
try:
    font = ImageFont.truetype("DejaVuSans-Bold.ttf", size=64)
except IOError:
    font = ImageFont.load_default(size=45)

for i, p in enumerate(png_files):
    img = Image.open(p).convert("RGB")
    draw = ImageDraw.Draw(img)

    # Extract iteration number from filename if present
    m = re.search(r"prob_hist_vowel_(\d+)", os.path.basename(p))
    iteration = m.group(1) if m else str(i)

    title = f"Iteration {iteration}"

    # Text position
    x, y = 20, 20

    # Optional: draw background box for readability
    text_bbox = draw.textbbox((x, y), title, font=font)
    draw.rectangle(text_bbox, fill=(255, 255, 255))

    # Draw text
    draw.text((x, y), title, fill=(0, 0, 0), font=font)

    frames.append(img)

gif_path = "log_plots/prob_hist_vowel.gif"

frames[0].save(
    gif_path,
    format="GIF",
    append_images=frames[1:],
    save_all=True,
    duration=600,  # ms per frame
    loop=0
)

print(f"Saved GIF to {gif_path}")

from PIL import Image, ImageDraw, ImageFont
import glob
import os
import re

png_files = sorted(glob.glob("log_plots/prob_hist_bad_*.png"))
png_files = [f"log_plots/prob_hist_bad_{i}.png" for i in range(len(png_files))]

frames = []

# Try to load a nicer font; fall back to default if unavailable
try:
    font = ImageFont.truetype("DejaVuSans-Bold.ttf", size=64)
except IOError:
    font = ImageFont.load_default(size=45)

for i, p in enumerate(png_files):
    img = Image.open(p).convert("RGB")
    draw = ImageDraw.Draw(img)

    # Extract iteration number from filename if present
    m = re.search(r"prob_hist_bad_(\d+)", os.path.basename(p))
    iteration = m.group(1) if m else str(i)

    title = f"Iteration {iteration}"

    # Text position
    x, y = 20, 20

    # Optional: draw background box for readability
    text_bbox = draw.textbbox((x, y), title, font=font)
    draw.rectangle(text_bbox, fill=(255, 255, 255))

    # Draw text
    draw.text((x, y), title, fill=(0, 0, 0), font=font)

    frames.append(img)

gif_path = "log_plots/prob_hist_bad.gif"

frames[0].save(
    gif_path,
    format="GIF",
    append_images=frames[1:],
    save_all=True,
    duration=600,  # ms per frame
    loop=0
)

print(f"Saved GIF to {gif_path}")
# Out:
# Saved GIF to log_plots/prob_hist_vowel.gif
# Saved GIF to log_plots/prob_hist_bad.gif

# %%
from PIL import Image, ImageDraw, ImageFont
import glob
import os
import re

png_files = sorted(glob.glob("log_plots/uncertainty_*.png"))
png_files = [f"log_plots/uncertainty_{i}.png" for i in range(len(png_files))]

frames = []

# Try to load a nicer font; fall back to default if unavailable
try:
    font = ImageFont.truetype("DejaVuSans-Bold.ttf", size=64)
except IOError:
    font = ImageFont.load_default(size=35)

for i, p in enumerate(png_files):
    img = Image.open(p).convert("RGB")
    draw = ImageDraw.Draw(img)

    # Extract iteration number from filename if present
    m = re.search(r"uncertainty_(\d+)", os.path.basename(p))
    iteration = m.group(1) if m else str(i)

    title = f"Iteration {iteration}"

    # Text position
    x, y = 20, 20

    # Optional: draw background box for readability
    text_bbox = draw.textbbox((x, y), title, font=font)
    draw.rectangle(text_bbox, fill=(255, 255, 255))

    # Draw text
    draw.text((x, y), title, fill=(0, 0, 0), font=font)

    frames.append(img)

gif_path = "log_plots/uncertainty.gif"

frames[0].save(
    gif_path,
    format="GIF",
    append_images=frames[1:],
    save_all=True,
    duration=600,  # ms per frame
    loop=0
)

print(f"Saved GIF to {gif_path}")
# Out:
# Saved GIF to log_plots/uncertainty.gif

# %%
from PIL import Image, ImageDraw, ImageFont
import glob
import os
import re

png_files = sorted(glob.glob("log_plots/cm_bad_*.png"))
png_files = [f"log_plots/cm_bad_{i}.png" for i in range(len(png_files))]

frames = []

# Try to load a nicer font; fall back to default if unavailable
try:
    font = ImageFont.truetype("DejaVuSans-Bold.ttf", size=64)
except IOError:
    font = ImageFont.load_default(size=45)

for i, p in enumerate(png_files):
    img = Image.open(p).convert("RGB")
    draw = ImageDraw.Draw(img)

    # Extract iteration number from filename if present
    m = re.search(r"cm_bad_(\d+)", os.path.basename(p))
    iteration = m.group(1) if m else str(i)

    title = f"Iteration {iteration}"

    # Text position
    x, y = 20, 20

    # Optional: draw background box for readability
    text_bbox = draw.textbbox((x, y), title, font=font)
    draw.rectangle(text_bbox, fill=(255, 255, 255))

    # Draw text
    draw.text((x, y), title, fill=(0, 0, 0), font=font)

    frames.append(img)

gif_path = "log_plots/cm_bad.gif"

frames[0].save(
    gif_path,
    format="GIF",
    append_images=frames[1:],
    save_all=True,
    duration=600,  # ms per frame
    loop=0
)

print(f"Saved GIF to {gif_path}")

from PIL import Image, ImageDraw, ImageFont
import glob
import os
import re

png_files = sorted(glob.glob("log_plots/cm_vowel_*.png"))
png_files = [f"log_plots/cm_vowel_{i}.png" for i in range(len(png_files))]

frames = []

# Try to load a nicer font; fall back to default if unavailable
try:
    font = ImageFont.truetype("DejaVuSans-Bold.ttf", size=64)
except IOError:
    font = ImageFont.load_default(size=45)

for i, p in enumerate(png_files):
    img = Image.open(p).convert("RGB")
    draw = ImageDraw.Draw(img)

    # Extract iteration number from filename if present
    m = re.search(r"cm_vowel_(\d+)", os.path.basename(p))
    iteration = m.group(1) if m else str(i)

    title = f"Iteration {iteration}"

    # Text position
    x, y = 20, 20

    # Optional: draw background box for readability
    text_bbox = draw.textbbox((x, y), title, font=font)
    draw.rectangle(text_bbox, fill=(255, 255, 255))

    # Draw text
    draw.text((x, y), title, fill=(0, 0, 0), font=font)

    frames.append(img)

gif_path = "log_plots/cm_vowel.gif"

frames[0].save(
    gif_path,
    format="GIF",
    append_images=frames[1:],
    save_all=True,
    duration=600,  # ms per frame
    loop=0
)

print(f"Saved GIF to {gif_path}")
# Out:
# Saved GIF to log_plots/cm_bad.gif
# Saved GIF to log_plots/cm_vowel.gif

# %%
from PIL import Image, ImageDraw, ImageFont
import glob
import os
import re

png_files = sorted(glob.glob("log_plots/roc_bad_*.png"))
png_files = [f"log_plots/roc_bad_{i}.png" for i in range(len(png_files))]

frames = []

# Try to load a nicer font; fall back to default if unavailable
try:
    font = ImageFont.truetype("DejaVuSans-Bold.ttf", size=64)
except IOError:
    font = ImageFont.load_default(size=45)

for i, p in enumerate(png_files):
    img = Image.open(p).convert("RGB")
    draw = ImageDraw.Draw(img)

    # Extract iteration number from filename if present
    m = re.search(r"roc_bad_(\d+)", os.path.basename(p))
    iteration = m.group(1) if m else str(i)

    title = f"Iteration {iteration}"

    # Text position
    x, y = 20, 20

    # Optional: draw background box for readability
    text_bbox = draw.textbbox((x, y), title, font=font)
    draw.rectangle(text_bbox, fill=(255, 255, 255))

    # Draw text
    draw.text((x, y), title, fill=(0, 0, 0), font=font)

    frames.append(img)

gif_path = "log_plots/roc_bad.gif"

frames[0].save(
    gif_path,
    format="GIF",
    append_images=frames[1:],
    save_all=True,
    duration=600,  # ms per frame
    loop=0
)

print(f"Saved GIF to {gif_path}")

from PIL import Image, ImageDraw, ImageFont
import glob
import os
import re

png_files = sorted(glob.glob("log_plots/roc_vowel_*.png"))
png_files = [f"log_plots/roc_vowel_{i}.png" for i in range(len(png_files))]

frames = []

# Try to load a nicer font; fall back to default if unavailable
try:
    font = ImageFont.truetype("DejaVuSans-Bold.ttf", size=64)
except IOError:
    font = ImageFont.load_default(size=45)

for i, p in enumerate(png_files):
    img = Image.open(p).convert("RGB")
    draw = ImageDraw.Draw(img)

    # Extract iteration number from filename if present
    m = re.search(r"roc_vowel_(\d+)", os.path.basename(p))
    iteration = m.group(1) if m else str(i)

    title = f"Iteration {iteration}"

    # Text position
    x, y = 20, 20

    # Optional: draw background box for readability
    text_bbox = draw.textbbox((x, y), title, font=font)
    draw.rectangle(text_bbox, fill=(255, 255, 255))

    # Draw text
    draw.text((x, y), title, fill=(0, 0, 0), font=font)

    frames.append(img)

gif_path = "log_plots/roc_vowel.gif"

frames[0].save(
    gif_path,
    format="GIF",
    append_images=frames[1:],
    save_all=True,
    duration=600,  # ms per frame
    loop=0
)

print(f"Saved GIF to {gif_path}")
# Out:
# Saved GIF to log_plots/roc_bad.gif
# Saved GIF to log_plots/roc_vowel.gif

# %%
from PIL import Image, ImageDraw, ImageFont
import glob
import os
import re

png_files = sorted(glob.glob("log_plots/val_curve_*.png"))
png_files = [f"log_plots/val_curve_{i}.png" for i in range(len(png_files))]

frames = []

# Try to load a nicer font; fall back to default if unavailable
try:
    font = ImageFont.truetype("DejaVuSans-Bold.ttf", size=64)
except IOError:
    font = ImageFont.load_default(size=45)

for i, p in enumerate(png_files):
    img = Image.open(p).convert("RGB")
    draw = ImageDraw.Draw(img)

    # Extract iteration number from filename if present
    m = re.search(r"prob_hist_(\d+)", os.path.basename(p))
    iteration = m.group(1) if m else str(i)

    title = f"Iteration {iteration}"

    # Text position
    x, y = 20, 20

    # Optional: draw background box for readability
    text_bbox = draw.textbbox((x, y), title, font=font)
    draw.rectangle(text_bbox, fill=(255, 255, 255))

    # Draw text
    draw.text((x, y), title, fill=(0, 0, 0), font=font)

    frames.append(img)

gif_path = "log_plots/val_curve.gif"

frames[0].save(
    gif_path,
    format="GIF",
    append_images=frames[1:],
    save_all=True,
    duration=600,  # ms per frame
    loop=0
)

print(f"Saved GIF to {gif_path}")
# Out:
# Saved GIF to log_plots/val_curve.gif

# %%
from PIL import Image, ImageDraw, ImageFont
import glob
import os
import re

png_files = sorted(glob.glob("log_plots/score_dist_bad_*.png"))
png_files = [f"log_plots/score_dist_bad_{i}.png" for i in range(len(png_files))]

frames = []

# Try to load a nicer font; fall back to default if unavailable
try:
    font = ImageFont.truetype("DejaVuSans-Bold.ttf", size=64)
except IOError:
    font = ImageFont.load_default(size=45)

for i, p in enumerate(png_files):
    img = Image.open(p).convert("RGB")
    draw = ImageDraw.Draw(img)

    # Extract iteration number from filename if present
    m = re.search(r"score_dist_bad_(\d+)", os.path.basename(p))
    iteration = m.group(1) if m else str(i)

    title = f"Iteration {iteration}"

    # Text position
    x, y = 20, 20

    # Optional: draw background box for readability
    text_bbox = draw.textbbox((x, y), title, font=font)
    draw.rectangle(text_bbox, fill=(255, 255, 255))

    # Draw text
    draw.text((x, y), title, fill=(0, 0, 0), font=font)

    frames.append(img)

gif_path = "log_plots/score_dist_bad.gif"

frames[0].save(
    gif_path,
    format="GIF",
    append_images=frames[1:],
    save_all=True,
    duration=600,  # ms per frame
    loop=0
)

print(f"Saved GIF to {gif_path}")

from PIL import Image, ImageDraw, ImageFont
import glob
import os
import re

png_files = sorted(glob.glob("log_plots/score_dist_vowel_*.png"))
png_files = [f"log_plots/score_dist_vowel_{i}.png" for i in range(len(png_files))]

frames = []

# Try to load a nicer font; fall back to default if unavailable
try:
    font = ImageFont.truetype("DejaVuSans-Bold.ttf", size=64)
except IOError:
    font = ImageFont.load_default(size=45)

for i, p in enumerate(png_files):
    img = Image.open(p).convert("RGB")
    draw = ImageDraw.Draw(img)

    # Extract iteration number from filename if present
    m = re.search(r"score_dist_vowel_(\d+)", os.path.basename(p))
    iteration = m.group(1) if m else str(i)

    title = f"Iteration {iteration}"

    # Text position
    x, y = 20, 20

    # Optional: draw background box for readability
    text_bbox = draw.textbbox((x, y), title, font=font)
    draw.rectangle(text_bbox, fill=(255, 255, 255))

    # Draw text
    draw.text((x, y), title, fill=(0, 0, 0), font=font)

    frames.append(img)

gif_path = "log_plots/score_dist_vowel.gif"

frames[0].save(
    gif_path,
    format="GIF",
    append_images=frames[1:],
    save_all=True,
    duration=600,  # ms per frame
    loop=0
)

print(f"Saved GIF to {gif_path}")
# Out:
# Saved GIF to log_plots/score_dist_bad.gif
# Saved GIF to log_plots/score_dist_vowel.gif

# %%
phone_embeds = []
for phone in target_basedataset.phone2id:
    embed = model.phone_emb(torch.tensor([target_basedataset.phone2id[phone]]).to("mps"))[0].cpu().detach().numpy()
    phone_embeds.append(embed)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

pca = PCA(n_components=2)
phone_embeds_2d = pca.fit_transform(np.array(phone_embeds))

plt.figure(figsize=(5,5))
plt.scatter(phone_embeds_2d[:,0], phone_embeds_2d[:,1], alpha=0.7, s=3)
plt.xlabel("PC 1")
plt.ylabel("PC 2")
for i, phone in enumerate(target_basedataset.phone2id):
    plt.text(phone_embeds_2d[i,0], phone_embeds_2d[i,1], phone, fontsize=9, ha='center', va='center')
plt.title("Phone Embeddings PCA Projection")
plt.savefig("phone_embeddings_pca.png", dpi=400)

# %%
phone_embeds_2d.shape

# %%
phone_embeds
